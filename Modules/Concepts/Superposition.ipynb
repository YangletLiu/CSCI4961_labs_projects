# %% [markdown]
# # IBM Quantum Composer
#
# https://quantum.ibm.com/composer/

# %% [markdown]
# ## Begin with one qubit in $\ket{0}$.

# %% [markdown]
# ![image.png](attachment:dcdbe75c-4e6f-47c0-bc76-a8e29ae7ada0.png)

# %% [markdown]
# ## Apply a Hadamard gate onto the qubit.

# %% [markdown]
# ![image.png](attachment:8582e170-5c68-4cc5-9b5c-ca07102ea4f2.png)

# %% [markdown]
# ## Measure each state, $\ket{0}$ and $\ket{1}$.

# %% [markdown]
# ![image.png](attachment:6ee5591a-2fea-44e7-94ef-fea08b277cc7.png)

# %% [markdown]
# ![image.png](attachment:6f76276d-d76c-42b0-9947-83411e959494.png)

# %% [markdown]
# ![image.png](attachment:ba2bbf26-9143-4088-901f-e39f8ebfc2f0.png)

# %% [markdown]
# <br>

# %% [markdown]
# # Qiskit Implementation

# %%
# %pip install qiskit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Imports

# %%
from qiskit import QuantumCircuit

# %% [markdown]
# ## Begin with one qubit in the initial state

# %%
circuit = QuantumCircuit(1)

circuit.draw(output="mpl")

# %% [markdown]
# ## Apply a Hadamard gate to the qubit.

# %%
circuit.h(0)

circuit.draw(output="mpl")
