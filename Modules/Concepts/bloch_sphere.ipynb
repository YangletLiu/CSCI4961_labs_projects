# %% [markdown]
# <span style="font-size: 24px;">Bloch Sphere: </span><span style="font-size: 14px;">A representation of quibit states in quantum computing</span>

# %% [markdown]
# ![{47515A69-6AD0-4DD3-A4E3-83345D19BD42}.png](attachment:{47515A69-6AD0-4DD3-A4E3-83345D19BD42}.png)

# %% [markdown]
# <span style="font-size: 14px;">There are 6 states in the Bloch sphere. North Pole denoted as ∣0⟩, South Pole denotated as ∣1⟩, ∣i+⟩, ∣i-⟩, ∣+⟩, and ∣-⟩</span>

# %% [markdown]
# <span style="font-size: 14px;"> </span>

# %% [markdown]
# ![{AD0F43A3-5381-416D-91AA-45E404595B25}.png](attachment:{AD0F43A3-5381-416D-91AA-45E404595B25}.png)

# %% [markdown]
# <span style="font-size: 14px;">There are 6 states in the Bloch sphere. North Pole denoted as ∣0⟩, South Pole denotated as ∣1⟩, ∣i+⟩, ∣i-⟩, ∣+⟩, and ∣-⟩</span>
