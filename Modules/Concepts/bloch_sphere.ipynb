# %% [markdown]
# # Bloch Sphere

# %% [markdown]
# A qubit on the Bloch sphere can indeed be represented as a vector with spherical coordinates θ and ϕ. These coordinates allow us to describe the qubit's state in terms of a unit vector pointing to a position on the sphere. We will demonstrate these states using qiskit.
#
# 1. [General Representation](#g)
# 2. [Computational Basis States](#i)
# 4. [Superposition States](#y)
# 8. [Summary](#summary)

# %% [markdown]
# ![{251DDDE1-4C51-4AC0-BFA6-85BF89860143}.png](attachment:{251DDDE1-4C51-4AC0-BFA6-85BF89860143}.png)

# %% [markdown]
# ## 1. General Representation of a Qubit on the Bloch Sphere
#
# A general single-qubit state ∣ψ⟩ can be written as:
#
# $$
# |\psi\rangle = \cos \left( \frac{\theta}{2} \right) |0\rangle + e^{i\phi} \sin \left( \frac{\theta}{2} \right) |1\rangle
# $$

# %% [markdown]
# ### 1.1 Computational Basis States
#
# |0⟩ and |1⟩ are the computational basis states located at the North and South poles of the Bloch Sphere.

# %% [markdown]
# #### |0⟩
#
# Using quiskit, we can plot the qubit state |0⟩ in cartesian coordinates and polar coordinates

# %%
#cartesian coordinates

# %%
#polar coordinates
plot_bloch_vector([1, 0, np.pi], coord_type='spherical')

# %% [markdown]
# ![{5B39BC54-B0B0-4DA8-8FE1-1729994A71EC}.png](attachment:{5B39BC54-B0B0-4DA8-8FE1-1729994A71EC}.png)

# %% [markdown]
# <span style="font-size: 16px;">Superposition States
#
# |+⟩ and ∣-⟩ are the superposition states located on the x-axis of the Bloch Sphere.
#
#
#
#
# </span></span>

# %% [markdown]
# <span style="font-size: 16px;">
# The |+⟩ corresponds to the plus state in the positive x-axis direction, and is defined as:
# </span></span>

# %% [markdown]
# ![{DD826E51-4105-41D5-906D-FD623B65A569}.png](attachment:{DD826E51-4105-41D5-906D-FD623B65A569}.png)

# %% [markdown]
# <span style="font-size: 16px;">
# The |-⟩ corresponds to the plus state in the negative x-axis direction, and is defined as:
# </span></span>

# %% [markdown]
# ![{0AFB9C37-2017-48B8-B281-36E84F1E28D6}.png](attachment:{0AFB9C37-2017-48B8-B281-36E84F1E28D6}.png)

# %% [markdown]
# <span style="font-size: 18px;">
# Other Superposition States in the y-Direction
# </span></span><span style="font-size: 16px;">
# |+i⟩ and ∣-i⟩ are the states with relaative phases between |0⟩ and ∣1⟩.</span></span>

# %% [markdown]
# <span style="font-size: 16px;">
# The |+i⟩ corresponds to the plus state in the positive y-axis direction, and is defined as:
# </span></span>

# %% [markdown]
# ![{D200755A-683B-4248-B459-B217D405DFC6}.png](attachment:{D200755A-683B-4248-B459-B217D405DFC6}.png)

# %% [markdown]
# <span style="font-size: 16px;">
# The |-i⟩ corresponds to the plus state in the negative y-axis direction, and is defined as:
# </span></span>

# %% [markdown]
# ![{FF32FA5C-E39B-4E1B-90B9-C2F224CF1E31}.png](attachment:{FF32FA5C-E39B-4E1B-90B9-C2F224CF1E31}.png)
